# %% [markdown]
# # json

# %% [markdown]
# 一种通用的数据交互格式\
# 在不同语言中交互\
# ![json格式.png](attachment:json格式.png)

# %% [markdown]
# ## python <-> json 相互转化

# %%
#用json模块
import json
#准备一个list
data = [{"name":"jack","age":11},{"name":"mary","age":12,},{"name":"wang","age":31}]
