# %% [markdown]
# # 异常的传递
# ![异常的传递性.png](attachment:异常的传递性.png)

# %%
def func1():
    print("execute func1")
    1/0
    print("finish func1")

def func2():
    print("execute func2")
    func1()
    print("finish func2")

def main():
    try:
        func2()
    except Exception as e:
        print(f"ERROR {e}")

main()
# Out:
# execute func2
# execute func1
# ERROR division by zero
