# %% [markdown]
# # 序列
# 连续 有序 支持下标索引

# %% [markdown]
# ## 切片
# 取出子序列
# ![切片.png](attachment:切片.png)

# %%
#list
my_list = [1,2,3,4,5,6,7]
new_list = my_list[0:5:2]
print(new_list)
#倒取
new_l = my_list[::-1]
print(new_l)
# Out:
# [1, 3, 5]
# [7, 6, 5, 4, 3, 2, 1]

# %%
#练习
str = 'asdlkCBA'
#得到abc
#1 切片
str1 = str[-1:-4:-1]
print(str1)

#2
# Out:
# ABC
